# %% [markdown]
# # Estadistica Aplicada
# ## Pandas
# ### 15 de agosto del 2022

# %%
import pandas as pd

# %%
alumnos = pd.read_csv('alumnos.csv')

# %%
alumnos
# Out:
#     Id            Nombre   Apellido  Calficación Final
# 0    1           ANTONIO     GARCIA                 73
# 1    2            MANUEL  FERNANDEZ                 19
# 2    3              JOSE   GONZALEZ                 38
# 3    4             DAVID      PEREZ                 14
# 4    5              JUAN      LOPEZ                 99
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66
# 6    7            JAVIER    SANCHEZ                 46
# 7    8         JOSE LUIS      GOMEZ                 89
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10
# 9   10            CARLOS       RUIZ                 62
# 10  11             JESUS     ALONSO                 94
# 11  12         ALEJANDRO  HERNANDEZ                 17
# 12  13            MIGUEL       DIAZ                 85
# 13  14       JOSE MANUEL  GUTIERREZ                 34
# 14  15            RAFAEL    ALVAREZ                 86
# 15  16      MIGUEL ANGEL     MORENO                100
# ...

# %%
alumnos.columns
# Out:
# Index(['Id', 'Nombre', 'Apellido', 'Calficación Final'], dtype='object')

# %%
alumnos.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
alumnos['Apellido']
# Out:
# 0        GARCIA
# 1     FERNANDEZ
# 2      GONZALEZ
# 3         PEREZ
# 4         LOPEZ
# 5     RODRIGUEZ
# 6       SANCHEZ
# 7         GOMEZ
# 8       JIMENEZ
# 9          RUIZ
# 10       ALONSO
# 11    HERNANDEZ
# 12         DIAZ
# 13    GUTIERREZ
# 14      ALVAREZ
# 15       MORENO
# 16        MUÑOZ
# 17       BLANCO
# 18          GIL
# 19      AGUIRRE
# 20         DIEZ
# 21      SALAZAR
# 22        RAMOS
# 23    DOMINGUEZ
# 24        ORTIZ
# 25       IBAÑEZ
# 26      RAMIREZ
# 27         SAEZ
# Name: Apellido, dtype: object

# %%
alumnos[['Nombre', 'Apellido']]
# Out:
#               Nombre   Apellido
# 0            ANTONIO     GARCIA
# 1             MANUEL  FERNANDEZ
# 2               JOSE   GONZALEZ
# 3              DAVID      PEREZ
# 4               JUAN      LOPEZ
# 5       JOSE ANTONIO  RODRIGUEZ
# 6             JAVIER    SANCHEZ
# 7          JOSE LUIS      GOMEZ
# 8   FRANCISCO JAVIER    JIMENEZ
# 9             CARLOS       RUIZ
# 10             JESUS     ALONSO
# 11         ALEJANDRO  HERNANDEZ
# 12            MIGUEL       DIAZ
# 13       JOSE MANUEL  GUTIERREZ
# 14            RAFAEL    ALVAREZ
# 15      MIGUEL ANGEL     MORENO
# 16             PEDRO      MUÑOZ
# 17             PABLO     BLANCO
# 18             ANGEL        GIL
# 19            SERGIO    AGUIRRE
# 20        JOSE MARIA       DIEZ
# 21          FERNANDO    SALAZAR
# 22             JORGE      RAMOS
# 23              LUIS  DOMINGUEZ
# 24           ALBERTO      ORTIZ
# 25       JUAN CARLOS     IBAÑEZ
# 26            ALVARO    RAMIREZ
# 27            ADRIAN       SAEZ

# %%
alumnos.iloc[:,2]
# Out:
# 0        GARCIA
# 1     FERNANDEZ
# 2      GONZALEZ
# 3         PEREZ
# 4         LOPEZ
# 5     RODRIGUEZ
# 6       SANCHEZ
# 7         GOMEZ
# 8       JIMENEZ
# 9          RUIZ
# 10       ALONSO
# 11    HERNANDEZ
# 12         DIAZ
# 13    GUTIERREZ
# 14      ALVAREZ
# 15       MORENO
# 16        MUÑOZ
# 17       BLANCO
# 18          GIL
# 19      AGUIRRE
# 20         DIEZ
# 21      SALAZAR
# 22        RAMOS
# 23    DOMINGUEZ
# 24        ORTIZ
# 25       IBAÑEZ
# 26      RAMIREZ
# 27         SAEZ
# Name: Apellido, dtype: object

# %%
alumnos.iloc[0:4,2]
# Out:
# 0       GARCIA
# 1    FERNANDEZ
# 2     GONZALEZ
# 3        PEREZ
# Name: Apellido, dtype: object

# %%
alumnos['Nueva Calificación'] = alumnos['Calficación Final']-5

# %%
alumnos
# Out:
#     Id            Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 0    1           ANTONIO     GARCIA                 73                  68
# 1    2            MANUEL  FERNANDEZ                 19                  14
# 2    3              JOSE   GONZALEZ                 38                  33
# 3    4             DAVID      PEREZ                 14                   9
# 4    5              JUAN      LOPEZ                 99                  94
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66                  61
# 6    7            JAVIER    SANCHEZ                 46                  41
# 7    8         JOSE LUIS      GOMEZ                 89                  84
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10                   5
# 9   10            CARLOS       RUIZ                 62                  57
# 10  11             JESUS     ALONSO                 94                  89
# ...

# %%
alumnos.head()
# Out:
#    Id   Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 0   1  ANTONIO     GARCIA                 73                  68
# 1   2   MANUEL  FERNANDEZ                 19                  14
# 2   3     JOSE   GONZALEZ                 38                  33
# 3   4    DAVID      PEREZ                 14                   9
# 4   5     JUAN      LOPEZ                 99                  94
#
#    Nueva calificación  Nueva Calificación
# 0                  68                  68
# 1                  14                  14
# 2                  33                  33
# 3                   9                   9
# 4                  94                  94

# %%
alumnos.tail()
# Out:
#     Id       Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 23  24         LUIS  DOMINGUEZ                 12                   7
# 24  25      ALBERTO      ORTIZ                 99                  94
# 25  26  JUAN CARLOS     IBAÑEZ                 43                  38
# 26  27       ALVARO    RAMIREZ                 40                  35
# 27  28       ADRIAN       SAEZ                  7                   2
#
#     Nueva calificación  Nueva Calificación
# 23                   7                   7
# 24                  94                  94
# 25                  38                  38
# 26                  35                  35
# 27                   2                   2

# %%
alumnos.describe()
# Out:
#               Id  Calficación Final  Nueva calificacion  Nueva calificación  \
# count  28.000000          28.000000           28.000000           28.000000
# mean   14.500000          52.000000           47.000000           47.000000
# std     8.225975          34.113102           34.113102           34.113102
# min     1.000000           1.000000           -4.000000           -4.000000
# 25%     7.750000          18.500000           13.500000           13.500000
# 50%    14.500000          48.500000           43.500000           43.500000
# 75%    21.250000          85.250000           80.250000           80.250000
# max    28.000000         100.000000           95.000000           95.000000
#
#        Nueva Calificación
# count           28.000000
# mean            47.000000
# std             34.113102
# min             -4.000000
# 25%             13.500000
# 50%             43.500000
# 75%             80.250000
# max             95.000000

# %%
alumnos.sort_values('Calficación Final')
# Out:
#     Id            Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 16  17             PEDRO      MUÑOZ                  1                  -4
# 19  20            SERGIO    AGUIRRE                  2                  -3
# 27  28            ADRIAN       SAEZ                  7                   2
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10                   5
# 23  24              LUIS  DOMINGUEZ                 12                   7
# 3    4             DAVID      PEREZ                 14                   9
# 11  12         ALEJANDRO  HERNANDEZ                 17                  12
# 1    2            MANUEL  FERNANDEZ                 19                  14
# 20  21        JOSE MARIA       DIEZ                 29                  24
# 13  14       JOSE MANUEL  GUTIERREZ                 34                  29
# 2    3              JOSE   GONZALEZ                 38                  33
# ...

# %%
alumnos.sort_values('Calficación Final',ascending=False)
# Out:
#     Id            Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 18  19             ANGEL        GIL                100                  95
# 15  16      MIGUEL ANGEL     MORENO                100                  95
# 24  25           ALBERTO      ORTIZ                 99                  94
# 4    5              JUAN      LOPEZ                 99                  94
# 10  11             JESUS     ALONSO                 94                  89
# 7    8         JOSE LUIS      GOMEZ                 89                  84
# 14  15            RAFAEL    ALVAREZ                 86                  81
# 12  13            MIGUEL       DIAZ                 85                  80
# 22  23             JORGE      RAMOS                 76                  71
# 0    1           ANTONIO     GARCIA                 73                  68
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66                  61
# ...

# %%
alumnos.sort_values(['Apellido', 'Nombre'],ascending=[True,True])
# Out:
#     Id            Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 19  20            SERGIO    AGUIRRE                  2                  -3
# 10  11             JESUS     ALONSO                 94                  89
# 14  15            RAFAEL    ALVAREZ                 86                  81
# 17  18             PABLO     BLANCO                 64                  59
# 12  13            MIGUEL       DIAZ                 85                  80
# 20  21        JOSE MARIA       DIEZ                 29                  24
# 23  24              LUIS  DOMINGUEZ                 12                   7
# 1    2            MANUEL  FERNANDEZ                 19                  14
# 0    1           ANTONIO     GARCIA                 73                  68
# 18  19             ANGEL        GIL                100                  95
# 7    8         JOSE LUIS      GOMEZ                 89                  84
# ...

# %%
alumnos[alumnos['Apellido']=='RUIZ']
# Out:
#    Id  Nombre Apellido  Calficación Final  Nueva calificacion  \
# 9  10  CARLOS     RUIZ                 62                  57
#
#    Nueva calificación  Nueva Calificación
# 9                  57                  57

# %%
alumnos[alumnos['Calficación Final']==100]
# Out:
#     Id        Nombre Apellido  Calficación Final  Nueva calificacion  \
# 15  16  MIGUEL ANGEL   MORENO                100                  95
# 18  19         ANGEL      GIL                100                  95
#
#     Nueva calificación  Nueva Calificación
# 15                  95                  95
# 18                  95                  95

# %%
alumnos[alumnos['Calficación Final']>70]
# Out:
#     Id        Nombre Apellido  Calficación Final  Nueva calificacion  \
# 0    1       ANTONIO   GARCIA                 73                  68
# 4    5          JUAN    LOPEZ                 99                  94
# 7    8     JOSE LUIS    GOMEZ                 89                  84
# 10  11         JESUS   ALONSO                 94                  89
# 12  13        MIGUEL     DIAZ                 85                  80
# 14  15        RAFAEL  ALVAREZ                 86                  81
# 15  16  MIGUEL ANGEL   MORENO                100                  95
# 18  19         ANGEL      GIL                100                  95
# 22  23         JORGE    RAMOS                 76                  71
# 24  25       ALBERTO    ORTIZ                 99                  94
#
#     Nueva calificación  Nueva Calificación
# 0                   68                  68
# 4                   94                  94
# 7                   84                  84
# ...

# %%
alumnos['Calficación Final'].mean()
# Out:
# 52.0

# %%
alumnos['Calficación Final'].std()
# Out:
# 34.113101642971486

# %%
import numpy as np

# %%
alumnos['Situación'] = np.where(alumnos['Calficación Final']>=70,'Aprobado','Reprobado')

# %%
alumnos
# Out:
#     Id            Nombre   Apellido  Calficación Final  Nueva calificacion  \
# 0    1           ANTONIO     GARCIA                 73                  68
# 1    2            MANUEL  FERNANDEZ                 19                  14
# 2    3              JOSE   GONZALEZ                 38                  33
# 3    4             DAVID      PEREZ                 14                   9
# 4    5              JUAN      LOPEZ                 99                  94
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66                  61
# 6    7            JAVIER    SANCHEZ                 46                  41
# 7    8         JOSE LUIS      GOMEZ                 89                  84
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10                   5
# 9   10            CARLOS       RUIZ                 62                  57
# 10  11             JESUS     ALONSO                 94                  89
# ...

# %%
alumnos.rename(columns={'Calficación Final':'cal_final'},inplace=True)

# %%
alumnos
# Out:
#     Id            Nombre   Apellido  cal_final  Nueva calificacion  \
# 0    1           ANTONIO     GARCIA         73                  68
# 1    2            MANUEL  FERNANDEZ         19                  14
# 2    3              JOSE   GONZALEZ         38                  33
# 3    4             DAVID      PEREZ         14                   9
# 4    5              JUAN      LOPEZ         99                  94
# 5    6      JOSE ANTONIO  RODRIGUEZ         66                  61
# 6    7            JAVIER    SANCHEZ         46                  41
# 7    8         JOSE LUIS      GOMEZ         89                  84
# 8    9  FRANCISCO JAVIER    JIMENEZ         10                   5
# 9   10            CARLOS       RUIZ         62                  57
# 10  11             JESUS     ALONSO         94                  89
# 11  12         ALEJANDRO  HERNANDEZ         17                  12
# 12  13            MIGUEL       DIAZ         85                  80
# ...

# %%
alumnos2 = alumnos[['Nombre', 'Apellido', 'Situación']]

# %%
alumnos2
# Out:
#               Nombre   Apellido  Situación
# 0            ANTONIO     GARCIA   Aprobado
# 1             MANUEL  FERNANDEZ  Reprobado
# 2               JOSE   GONZALEZ  Reprobado
# 3              DAVID      PEREZ  Reprobado
# 4               JUAN      LOPEZ   Aprobado
# 5       JOSE ANTONIO  RODRIGUEZ  Reprobado
# 6             JAVIER    SANCHEZ  Reprobado
# 7          JOSE LUIS      GOMEZ   Aprobado
# 8   FRANCISCO JAVIER    JIMENEZ  Reprobado
# 9             CARLOS       RUIZ  Reprobado
# 10             JESUS     ALONSO   Aprobado
# 11         ALEJANDRO  HERNANDEZ  Reprobado
# 12            MIGUEL       DIAZ   Aprobado
# 13       JOSE MANUEL  GUTIERREZ  Reprobado
# 14            RAFAEL    ALVAREZ   Aprobado
# 15      MIGUEL ANGEL     MORENO   Aprobado
# 16             PEDRO      MUÑOZ  Reprobado
# 17             PABLO     BLANCO  Reprobado
# 18             ANGEL        GIL   Aprobado
# 19            SERGIO    AGUIRRE  Reprobado
# 20        JOSE MARIA       DIEZ  Reprobado
# ...

# %%
alumnos.groupby('Situación').count() #Agrupa y cuenta cuandos aprobados y reprobados hay
# Out:
#            Id  Nombre  Apellido  cal_final  Nueva calificacion  \
# Situación
# Aprobado   10      10        10         10                  10
# Reprobado  18      18        18         18                  18
#
#            Nueva calificación  Nueva Calificación
# Situación
# Aprobado                   10                  10
# Reprobado                  18                  18

# %%
alumnos.groupby('Situación').mean() #promedio de cada columna
# Out:
#              Id  cal_final  Nueva calificacion  Nueva calificación  \
# Situación
# Aprobado   13.6  90.100000           85.100000           85.100000
# Reprobado  15.0  30.833333           25.833333           25.833333
#
#            Nueva Calificación
# Situación
# Aprobado            85.100000
# Reprobado           25.833333

# %%
alumnos.groupby('Situación').mean()['cal_final'] #promedio solo de una columna
# Out:
# Situación
# Aprobado     90.100000
# Reprobado    30.833333
# Name: cal_final, dtype: float64
